# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#       Unnamed: 0    #                            Name            Type  Total  \
# 0              0    1                       Bulbasaur    Grass Poison    318
# 1              1    2                         Ivysaur    Grass Poison    405
# 2              2    3                        Venusaur    Grass Poison    525
# 3              3    3          Venusaur Mega Venusaur    Grass Poison    625
# 4              4    4                      Charmander            Fire    309
# ...          ...  ...                             ...             ...    ...
# 1024        1024  888     Zacian Hero of Many Battles           Fairy    670
# 1025        1025  889        Zamazenta Crowned Shield  Fighting Steel    720
# 1026        1026  889  Zamazenta Hero of Many Battles        Fighting    670
# 1027        1027  890                       Eternatus   Poison Dragon    690
# 1028        1028  890             Eternatus Eternamax   Poison Dragon   1125
#
# ...

# %%
df.sort_values()

# %%
conn = sqlite3.connect('pokemon.db')

c = conn.cursor()

c.execute("SELECT Name FROM pokemon WHERE ID=150")

print(c.fetchone())
# Out:
# ('Mewtwo',)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '#', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed'],
#       dtype='object')

# %%
df['HP']
# Out:
# 0        45
# 1        60
# 2        80
# 3        80
# 4        39
#        ...
# 1024     92
# 1025     92
# 1026     92
# 1027    140
# 1028    255
# Name: HP, Length: 1029, dtype: int64

# %%
for index in range(df.shape[0]):
    print(df['Name'][index])
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# Venusaur Mega Venusaur
# Charmander
# Charmeleon
# Charizard
# Charizard Mega Charizard X
# Charizard Mega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# Blastoise Mega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# Beedrill Mega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# Pidgeot Mega Pidgeot
# Rattata
# Rattata Alolan Rattata
# Raticate
# Raticate Alolan Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Pikachu Partner Pikachu
# Raichu
# Raichu Alolan Raichu
# Sandshrew
# Sandshrew Alolan Sandshrew
# Sandslash
# Sandslash Alolan Sandslash
# Nidoran♀
# Nidorina
# Nidoqueen
# Nidoran♂
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Vulpix Alolan Vulpix
# Ninetales
# Ninetales Alolan Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Diglett Alolan Diglett
# Dugtrio
# Dugtrio Alolan Dugtrio
# Meowth
# Meowth Alolan Meowth
# ...
